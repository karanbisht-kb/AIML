# %%
# !pip install mittens numpy scipy scikit-learn
# Out:
# Collecting mittens
#   Downloading mittens-0.2-py3-none-any.whl.metadata (377 bytes)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (1.16.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Downloading mittens-0.2-py3-none-any.whl (15 kB)
# Installing collected packages: mittens
# Successfully installed mittens-0.2

# %%
from mittens import GloVe
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd

# %%
corpus = [
    "I like natural language processing",
    "Natural language processing is fun",
    "I enjoy learning NLP",
]

# Tokenize and build co-occurrence matrix
vectorizer = CountVectorizer(token_pattern=r"(?u)\b\w+\b")
X = vectorizer.fit_transform(corpus)
Xc = (X.T * X)  # co-occurrence counts matrix
Xc.setdiag(0)   # remove self-cooccurrence
coocc = Xc.toarray()
vocab = vectorizer.get_feature_names_out()

#print("Vocabulary dict:", vectorizer.vocabulary_)
#print ("vectorizer.fit_transform(corpus) :" ,X)
#print ("(X.T * X)  # co-occurrence counts matrix : " ,Xc)
#print (coocc)
#print (vocab)

# %%
df = pd.DataFrame(coocc, index=vocab, columns=vocab)
#print(df)

# Train model
glove = GloVe(n=50, max_iter=300)
embeddings = glove.fit(coocc)

# print co-occurrence counts matrix
# print (coocc)
# Word-to-index map
word2idx = {w: i for i, w in enumerate(vocab)}
print("Embedding for 'nlp':", embeddings[word2idx['nlp']])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/training/adagrad.py:138: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Iteration 190: loss: 0.00012916808191221207
# Embedding for 'nlp': [ 0.24864568 -0.12206301  0.4009297  -0.01890136 -0.3192826  -0.19493093
#  -0.12359902 -0.09431508 -0.06357582 -0.4205674  -0.10352637 -0.09165383
#  -0.1719235  -0.42993623 -0.0158049   0.4209262   0.2835635  -0.17193937
#   0.27578452  0.1675101  -0.11845635 -0.17122363  0.22542448 -0.17014581
#   0.338284   -0.13589463 -0.0034766  -0.12679237 -0.02406363  0.10693546
#  -0.07568753 -0.3986097   0.20262079 -0.02084559 -0.04336952  0.03927378
#   0.09251907  0.42840478 -0.06834593 -0.06192996  0.01102328  0.00917526
#   0.27902713  0.39271164 -0.10182031  0.09145057 -0.09507909  0.17034826
#   0.3317883   0.314692  ]
