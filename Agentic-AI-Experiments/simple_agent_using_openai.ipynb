# %%
from openai import OpenAI

# Create a client (reads OPENAI_API_KEY from env)
from google.colab import userdata


client = OpenAI(api_key=userdata.get('openAiKey'))

SYSTEM_PROMPT = """
You are a helpful AI agent.
- Answer clearly and concisely.
- Ask for clarification only when truly needed.
"""

def run_agent():
    print("Simple AI agent. Type 'quit' to exit.\n")

    while True:
        user_input = input("You: ")
        if user_input.strip().lower() in {"quit", "exit"}:
            print("Agent: Goodbye! 👋")
            break

        # Call the LLM via Responses API
        response = client.responses.create(
            model="gpt-5-mini",   # or gpt-4.1-mini, etc.
            input=[
                {"role": "system", "content": SYSTEM_PROMPT},
                {"role": "user", "content": user_input},
            ],
        )

        # Convenient helper: output_text aggregates all text output
        agent_reply = response.output_text
        print(f"Agent: {agent_reply}\n")


if __name__ == "__main__":
    run_agent()
# Out:
# Simple AI agent. Type 'quit' to exit.
#
# You: Who is boris johnson?
# Agent: Boris Johnson (full name Alexander Boris de Pfeffel Johnson; born 19 June 1964) is a British politician, writer and former journalist best known for serving as Prime Minister of the United Kingdom from July 2019 to September 2022. He led the Conservative Party during that period.
#
# Key facts
# - Political offices: Prime Minister (2019–2022); Leader of the Conservative Party (2019–2022); Mayor of London (2008–2016); Foreign Secretary (2016–2018). He was a Member of Parliament at various times (Henley 2001–2008; Uxbridge and South Ruislip 2015–2023).
# - Brexit: A prominent supporter of Leave in the 2016 EU referendum, he became a leading figure in implementing Brexit as PM. His government negotiated the post‑Brexit relationship with the EU (the Trade and Cooperation Agreement).
# - COVID and controversies: His premiership was marked by the COVID-19 pandemic and by scandals over social gatherings in government offices during lockdown (“Partygate”). He received a police fixed penalty notice for breaching COVID rules and later a parliamentary committee concluded he had misled Parliament about the matter.
# - Resignation and aftermath: Facing mass ministerial resignations and loss of party support, he announced his intention to step down in July 2022 and left office in September 2022. He subsequently resigned his parliamentary seat in June 2023. He remains a high‑profile public figure and commentator.
#
# Background and career before politics
# - Born in New York City, educated at Eton College and Balliol College, Oxford (classics), where he was president of the Oxford Union.
# - Worked as a journalist and columnist and was editor of The Spectator (1999–2005) before returning to frontline politics.
#
# Personality and public image
# - Known for a flamboyant, often humorous or eccentric public style, and for both strong popularity and sharp criticism. His tenure reshaped UK politics through Brexit and provoked strong debate over governance and standards.
#
# If you want, I can provide a more detailed timeline of his life and career, explain specific controversies (Partygate, the Privileges Committee finding), or summarize his major policies as prime minister. Which would you like?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3918970856.py in <cell line: 0>()
#      37
#      38 if __name__ == "__main__":
# ---> 39     run_agent()
#
# /tmp/ipython-input-3918970856.py in run_agent()
#      17
#      18     while True:
# ---> 19         user_input = input("You: ")
#      20         if user_input.strip().lower() in {"quit", "exit"}:
#      21             print("Agent: Goodbye! 👋")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
