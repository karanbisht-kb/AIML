# %% [markdown]
# <a href="https://colab.research.google.com/github/karanbisht-kb/AIML/blob/main/openAI_SearchEngine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from openai import OpenAI

from google.colab import userdata
# Create a client (reads OPENAI_API_KEY from env)
client = OpenAI(api_key=userdata.get('openAiKey'))

SYSTEM_PROMPT = """
You are a helpful AI agent.
- Answer clearly and concisely.
- Ask for clarification only when truly needed.
"""

def run_agent():
    print("Simple AI agent. Type 'quit' to exit.\n")

    while True:
        user_input = input("You: ")
        if user_input.strip().lower() in {"quit", "exit"}:
            print("Agent: Goodbye! 👋")
            break

        # Call the LLM via Responses API
        response = client.responses.create(
            model="gpt-5-mini",   # or gpt-4.1-mini, etc.
            input=[
                {"role": "system", "content": SYSTEM_PROMPT},
                {"role": "user", "content": user_input},
            ],
        )

        # Convenient helper: output_text aggregates all text output
        agent_reply = response.output_text
        print(f"Agent: {agent_reply}\n")


if __name__ == "__main__":
    run_agent()
# Out:
# Simple AI agent. Type 'quit' to exit.
#
# You: Hi
# Agent: Hello! How can I help you today?
#
# You: HCL address
# Agent: Do you mean the company HCL (HCL Technologies / HCLTech), something else named HCL, or did you mean HCl (hydrochloric acid)? If you mean the company, which country or city/office do you need the address for (corporate HQ, registered office, or a local branch)?
#
# You: Yes
# Agent: Thanks — how can I help? Do you mean "Yes" to proceed with something we discussed, or do you have a new request?
#
# You: HCLTech
# Agent: Do you mean the company HCLTech (formerly HCL Technologies)? If so, here’s a short snapshot — tell me which areas you want more detail on (e.g., services, financials, recent news, stock, careers, competitors, partnerships, or a slide-ready summary).
#
# Quick snapshot
# - Name: HCLTech (brand name of HCL Technologies Limited)
# - Founded: HCL Technologies established in 1991 (parent HCL founded 1976)
# - Headquarters: Noida, India
# - CEO & MD: C. Vijayakumar (Vijay)
# - Business: Global IT services and digital/engineering services provider (applications, cloud, infrastructure, R&D engineering, cybersecurity, digital consulting, business process services, and product/platform engineering)
# - Scale: One of India’s largest IT services firms with a global presence across many countries and hundreds of thousands of employees
# - Notable: Rebranded to HCLTech in 2022; operates HCLSoftware (software products and platforms) and invests in automation and AI-enabled platforms
# - Clients/Industries: Serves banking/financial services, manufacturing, healthcare, telecom, retail, public sector, and others
#
# What would you like next?
# - Detailed company profile or timeline
# - Latest financials and performance (note: I can’t fetch live market data without your input)
# - Recent news and strategic moves (I can summarize through mid‑2024; need permission to fetch live web updates)
# - Career opportunities and hiring tips
# - Comparison with competitors (TCS, Infosys, Wipro, etc.)
# - Prepare a short slide or executive summary
#
# Which do you want?
