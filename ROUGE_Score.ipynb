# %% [markdown]
# <a href="https://colab.research.google.com/github/karanbisht-kb/AIML/blob/main/ROUGE_Score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rouge-score
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=871744a3994cecfc71c8f48e405f8372f4819c843c03aed6ce69d71b5e53f0a8
#   Stored in directory: /root/.cache/pip/wheels/85/9d/af/01feefbe7d55ef5468796f0c68225b6788e85d9d0a281e7a70
# Successfully built rouge-score
# ...

# %%
from rouge_score import rouge_scorer

# Reference (ground truth)
reference = "The cat is sitting on the mat"

# Candidate (LLM output)
generated = "The cat is on the mat"

# Initialize scorer
scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)

# Compute scores
scores = scorer.score(reference, generated)

print("ROUGE Scores:")
for key, value in scores.items():
    print(f"{key}: Precision={value.precision:.4f}, Recall={value.recall:.4f}, F1={value.fmeasure:.4f}")
# Out:
# ROUGE Scores:
# rouge1: Precision=1.0000, Recall=0.8571, F1=0.9231
# rouge2: Precision=0.8000, Recall=0.6667, F1=0.7273
# rougeL: Precision=1.0000, Recall=0.8571, F1=0.9231
