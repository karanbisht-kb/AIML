# %% [markdown]
# <a href="https://colab.research.google.com/github/karanbisht-kb/AIML/blob/main/text-to-speech-opensource.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gTTS

from gtts import gTTS
import os
# Inspect the TTS object to find available methods
mytext = 'Welcome to Google Text-to-Speech'
language = 'en'
myobj = gTTS(text=mytext, lang=language, slow=False)
myobj.save("welcome.mp3")
os.system("mpg321 welcome.mp3")

#from gtts import gTTS
#tts = gTTS("Hello from the GenAI class!", lang="en")
#tts.save("output.mp3")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 4.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.3.0
#     Uninstalling click-8.3.0:
#       Successfully uninstalled click-8.3.0
# ...
# 32512
